# %% [markdown]
# Hubbard Atom
# =======
#
# We calculate the Green function for the Hubbard atom with the Hamiltonian
#
# $$h_{\rm loc} = h_0 + h_{\rm int}$$
#
# where
#
# $$h_0 = -\mu \, (n_{\uparrow, 0} + n_{\uparrow, 0}) - h(n_{\uparrow,0} - n_{\downarrow,0})$$
#
# and
#
# $$h_{\rm int} = U n_{\uparrow, 0} n_{\downarrow, 0}$$
#
# The parameters are defined below.

# %%
# %load model.py
import sys, os
sys.path.append(os.getcwd() + '/../common')
from util import *

from triqs.gf import Gf, MeshImFreq, iOmega_n, inverse
from triqs.operators import c, c_dag, n
from itertools import product

# ==== System Parameters ====
beta = 5.           # Inverse temperature
mu = 2.             # Chemical potential
U = 5.              # On-site density-density interaction
h = 0.2             # Local magnetic field

spin_names = ['up', 'dn']
orb_names  = [0]

# ==== Local Hamiltonian ====
h_0 = - mu*( n('up',0) + n('dn',0) ) - h*( n('up',0) - n('dn',0) )
h_int = U * n('up',0) * n('dn',0)
h_imp = h_0 + h_int

# ==== Bath & Coupling Hamiltonian ====
h_bath, h_coup = 0, 0

# ==== Total impurity hamiltonian and fundamental operators ====
h_tot = h_imp + h_coup + h_bath

# ==== Green function structure ====
gf_struct = [ [s, orb_names] for s in spin_names ]

# ==== Hybridization Function ====
n_iw = int(10 * beta)
iw_mesh = MeshImFreq(beta, 'Fermion', n_iw)
Delta = BlockGf(mesh=iw_mesh, gf_struct=gf_struct)
Delta << 0.0;

# ==== Non-Interacting Impurity Green function  ====
G0_iw = BlockGf(mesh=iw_mesh, gf_struct=gf_struct)
G0_iw['up'] << inverse(iOmega_n + mu + h - Delta['up'])
G0_iw['dn'] << inverse(iOmega_n + mu - h - Delta['dn'])
# Out:
# Greens Function G_dn with mesh Matsubara Freq Mesh of size 100, Domain: Matsubara domain with beta = 5, statistic = Fermion, positive_only : 0 and target_rank 2:

# %% [markdown]
# Results
# ====

# %%
from triqs.plot.mpl_interface import oplot, plt
# %matplotlib inline

# %%
# %load ../common/plot.py
import sys, os
sys.path.append(os.getcwd() + "/..")
sys.path.append(os.getcwd() + "/../../common")
from model import *

from h5 import HDFArchive
from triqs.plot.mpl_interface import oplot, plt
from glob import glob
from os.path import basename

# === Load Green function for every solver and calculate self-energy

solver_lst = [ basename(f).strip('.h5') for f in glob('results/*.h5') ]
marker_lst = ['-x', '-+', '-^', '-v', '-<', '->']
G, Sigma = {}, {}

for solver in solver_lst:
    dat = HDFArchive('results/' + solver + '.h5','r')
    G[solver] = dat['G']
    Sigma[solver] = G0_iw.copy()
    Sigma[solver] << inverse(G0_iw) - inverse(G[solver])

# === For every block and solver, plot Green function and Self energy

block_lst = list(G[solver_lst[0]].indices)
n_blocks = len(block_lst)

for g, name in [[G, 'G'], [Sigma, '$\Sigma$']]:

    plt.subplots(n_blocks,1,figsize=(10,6*n_blocks))

    for i, block in enumerate(block_lst,1):
        fig = plt.subplot(n_blocks,1,i)
        fig.set_title(name + "[" + block + "]")
        for solver in solver_lst:
            marker = marker_lst[solver_lst.index(solver)]
            oplot(g[solver][block][0,0], marker, name = name + "[0,0]_%s" % solver)
        plt.xlabel("$\omega_n$")
        plt.ylabel(name + "[" + block + "]$(i\omega_n)$")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Deviations
# ======
#
# We present a table containing deviations between the different solvers measured via
#
# $$||G_{\rm Solver_1} - G_{\rm Solver_2}||_\infty$$

# %%
import numpy as np

norm_inf = lambda G : np.amax(np.abs(G.data))

for block in block_lst:
    deviations = [[ norm_inf(G[s1][block] - G[s2][block]) for s1 in solver_lst ] \
                    for s2 in solver_lst ]
    
    print("\t\t    Deviations for Block " + block)
    print("\t\t -----------------------------------")

    row_format ="{:>15}" * (len(solver_lst) + 1)
    print(row_format.format("", *solver_lst))
    row_format ="{:>15}" + "{:>15.2E}" * len(solver_lst)
    for solver, row in zip(solver_lst, deviations):
        print(row_format.format(solver, *row))
        
    print("\n\n")
# Out:
# 		    Deviations for Block up
# 		 -----------------------------------
#                          ctint          exact           pyed     alps_cthyb        pomerol
#           ctint       0.00E+00       1.49E-04       1.49E-04       4.22E-04       1.49E-04
#           exact       1.49E-04       0.00E+00       7.85E-17       4.22E-04       9.31E-17
#            pyed       1.49E-04       7.85E-17       0.00E+00       4.22E-04       5.72E-17
#      alps_cthyb       4.22E-04       4.22E-04       4.22E-04       0.00E+00       4.22E-04
#         pomerol       1.49E-04       9.31E-17       5.72E-17       4.22E-04       0.00E+00
#
#
#
# 		    Deviations for Block dn
# 		 -----------------------------------
#                          ctint          exact           pyed     alps_cthyb        pomerol
#           ctint       0.00E+00       4.35E-04       4.35E-04       3.38E-04       4.35E-04
#           exact       4.35E-04       0.00E+00       1.96E-16       4.80E-04       1.69E-16
#            pyed       4.35E-04       1.96E-16       0.00E+00       4.80E-04       3.10E-17
#      alps_cthyb       3.38E-04       4.80E-04       4.80E-04       0.00E+00       4.80E-04
#         pomerol       4.35E-04       1.69E-16       3.10E-17       4.80E-04       0.00E+00

# %% [markdown]
# Two-particle Green's function
# ======

# %%
marker_only_lst = ['x', '+', '^', 'v', '<', '>']

G2_ph_AABB = {}
G2_ph_ABBA = {}
for solver in solver_lst:
    dat = HDFArchive('results/' + solver + '.h5','r')
    if 'G2_iw_inu_inup_ph_AABB' not in dat:
        continue
    G2_ph_AABB[solver] = dat['G2_iw_inu_inup_ph_AABB']
    G2_ph_ABBA[solver] = dat['G2_iw_inu_inup_ph_ABBA']
list(G2_ph_AABB.keys())
# Out:
# ['pomerol']

# %% [markdown]
# # AABB (real part)

# %%
fig, axes = plt.subplots(n_blocks,1,figsize=(10,3*n_blocks**2))
solver_lst_g2 = list(G2_ph_AABB.keys())
for solver in solver_lst_g2:
    for i, (b1, b2) in enumerate(product(block_lst, repeat=2)):
        fig = plt.subplot(n_blocks**2, 1, i+1)
        fig.set_title('({}, {})'.format(b1, b2))
        fig.plot(G2_ph_AABB[solver][(b1, b2)].data.ravel().real, marker=marker_only_lst[solver_lst_g2.index(solver)], ls='', label=solver)
fig.legend()
plt.tight_layout()

# %% [markdown]
# # AABB (imag part)

# %%
fig, axes = plt.subplots(n_blocks,1,figsize=(10,3*n_blocks**2))
solver_lst_g2 = list(G2_ph_AABB.keys())
for solver in solver_lst_g2:
    for i, (b1, b2) in enumerate(product(block_lst, repeat=2)):
        fig = plt.subplot(n_blocks**2, 1, i+1)
        fig.set_title('({}, {})'.format(b1, b2))
        fig.plot(G2_ph_AABB[solver][(b1, b2)].data.ravel().imag, marker=marker_only_lst[solver_lst_g2.index(solver)], ls='', label=solver)
fig.legend()
plt.tight_layout()

# %% [markdown]
# # ABBA (real)

# %%
fig, axes = plt.subplots(n_blocks,1,figsize=(10,3*n_blocks**2))
solver_lst_g2 = list(G2_ph_ABBA.keys())
for solver in solver_lst_g2:
    for i, (b1, b2) in enumerate(product(block_lst, repeat=2)):
        fig = plt.subplot(n_blocks**2, 1, i+1)
        fig.set_title('({}, {})'.format(b1, b2))
        fig.plot(G2_ph_ABBA[solver][(b1, b2)].data.ravel().real, marker=marker_only_lst[solver_lst_g2.index(solver)], ls='', label=solver)
fig.legend()
plt.tight_layout()

# %% [markdown]
# # ABBA (imag)

# %%
fig, axes = plt.subplots(n_blocks,1,figsize=(10,3*n_blocks**2))
solver_lst_g2 = list(G2_ph_ABBA.keys())
for solver in solver_lst_g2:
    for i, (b1, b2) in enumerate(product(block_lst, repeat=2)):
        fig = plt.subplot(n_blocks**2, 1, i+1)
        fig.set_title('({}, {})'.format(b1, b2))
        fig.plot(G2_ph_ABBA[solver][(b1, b2)].data.ravel().imag, marker=marker_only_lst[solver_lst_g2.index(solver)], ls='', label=solver)
fig.legend()
plt.tight_layout()
